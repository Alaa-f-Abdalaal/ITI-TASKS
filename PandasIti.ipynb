# %% [markdown]
# <a href="https://colab.research.google.com/github/Alaa-f-Abdalaal/ITI-TASKS/blob/main/PandasIti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Import pandas
import pandas as pd
import numpy as np

file_path = '//content/drive/MyDrive/Purchase_Data.csv'
df = pd.read_csv(file_path)


print("CSV file loaded successfully! Here are the first few rows:")
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CSV file loaded successfully! Here are the first few rows:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price
# 0    2.0
# 1    2.0
# 2    2.0
# 3    6.0
# 4    6.0

# %%
df.dtypes
# Out:
# invoice_number    float64
# invoice_time       object
# store_id           object
# product_id          int64
# category_id         int64
# num_item          float64
# price             float64
# dtype: object

# %%
result1=df.loc[:,df.columns[0:2]]
result1
# Out:
#       invoice_number   invoice_time
# 0       2.020000e+11  7/15/15 10:45
# 1       2.020000e+11  7/15/15 12:16
# 2       2.020000e+11  7/15/15 12:16
# 3       2.020000e+11  7/15/15 12:16
# 4       2.020000e+11  7/15/15 12:16
# ...              ...            ...
# 5377    2.020000e+11   9/5/15 23:07
# 5378    2.020000e+11   9/5/15 23:23
# 5379    2.020000e+11   9/5/15 23:24
# 5380    2.020000e+11   9/5/15 23:32
# 5381    2.020000e+11   9/5/15 23:38
#
# [5382 rows x 2 columns]

# %%
result_2=df.loc[:1,:]
result_2
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
#
#    price
# 0    2.0
# 1    2.0

# %%
result_3=df.loc[:3,df.columns[:5]]
result_3
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401

# %%
result_4=df.loc[[0,4,6],["invoice_time","price"]]
result_4
# Out:
#     invoice_time  price
# 0  7/15/15 10:45    2.0
# 4  7/15/15 12:16    6.0
# 6  7/15/15 15:28    2.0

# %%
num_rows = df.shape[0]
print("Number of rows:", num_rows)
# Out:
# Number of rows: 5382

# %%
print(df.loc[num_rows-1])
# Out:
# invoice_number    202000000000.0
# invoice_time        9/5/15 23:38
# store_id                    G619
# product_id              23030206
# category_id               210101
# num_item                     1.0
# price                        2.0
# Name: 5381, dtype: object

# %%
import pandas as pd
avg_price=df["price"].mean
print("Average Price:", avg_price)
max_price = df["price"].max()

print("Max Price:", max_price)
# Out:
# Average Price: <bound method Series.mean of 0       2.0
# 1       2.0
# 2       2.0
# 3       6.0
# 4       6.0
#        ...
# 5377    3.0
# 5378    6.0
# 5379    5.0
# 5380    2.0
# 5381    2.0
# Name: price, Length: 5382, dtype: float64>
# Max Price: 6.01

# %%
avg_price, avg_num_items = df[["price", "num_item"]].mean()
print("Avg Price:", avg_price)
print("Avg Num Items:", avg_num_items)
# Out:
# Avg Price: 3.1920522110741363
# Avg Num Items: 1.2983091787439613

# %%
df["total"] = df["price"] * df["num_item"]
print(df.head())
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price  total
# 0    2.0    2.0
# 1    2.0    2.0
# 2    2.0    2.0
# 3    6.0    6.0
# 4    6.0    6.0

# %%
avg_top3 = df.nlargest(3, "price")["price"].mean()
print("Avg price of top 3 expensive purchases:", avg_top3)
# Out:
# Avg price of top 3 expensive purchases: 6.003333333333333

# %%
num_products = df["product_id"].nunique()
print("Number of different products:", num_products)
# Out:
# Number of different products: 53

# %%
stats_total = df["total"].describe()
diff_mean_median = stats_total["mean"] - stats_total["50%"]
print("Difference:", diff_mean_median)
# Out:
# Difference: 0.9318078781127839

# %%
df.drop("total", axis=1, inplace=True)
print(df.head())
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price
# 0    2.0
# 1    2.0
# 2    2.0
# 3    6.0
# 4    6.0

# %%
df["invoice_time"] = pd.to_datetime(df["invoice_time"])
print(df.dtypes)
# Out:
# /tmp/ipython-input-862921537.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["invoice_time"] = pd.to_datetime(df["invoice_time"])
# invoice_number           float64
# invoice_time      datetime64[ns]
# store_id                  object
# product_id                 int64
# category_id                int64
# num_item                 float64
# price                    float64
# dtype: object

# %%
df["DOW"] = df["invoice_time"].dt.day_name()
df["Month"] = df["invoice_time"].dt.month_name()
print(df.head())
# Out:
#    invoice_number        invoice_time store_id  product_id  category_id  \
# 0    2.020000e+11 2015-07-15 10:45:00     G816     7000300       210101
# 1    2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 2    2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 3    2.020000e+11 2015-07-15 12:16:00     G816     7070891        70401
# 4    2.020000e+11 2015-07-15 12:16:00     G816     7090363        70401
#
#    num_item  price        DOW Month
# 0       1.0    2.0  Wednesday  July
# 1       1.0    2.0  Wednesday  July
# 2       1.0    2.0  Wednesday  July
# 3       1.0    6.0  Wednesday  July
# 4       1.0    6.0  Wednesday  July

# %%
num_purchases_wed = df["DOW"].value_counts()["Wednesday"]
print("Purchases on Wednesday:", num_purchases_wed)
# Out:
# Purchases on Wednesday: 959

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Import pandas
import pandas as pd
import numpy as np

file_path = '/content/drive/MyDrive/Titanic.csv'
df = pd.read_csv(file_path)


print("CSV file loaded successfully! Here are the first few rows:")
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CSV file loaded successfully! Here are the first few rows:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# ...

# %%
df.set_index("PassengerId", inplace=True)
print(df.head())
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
print(df.loc[896, "Name"])
# Out:
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)

# %%
df.reset_index(inplace=True)
print(df.head())
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
missing_age = df["Age"].isnull().sum()
print("Missing Age entries:", missing_age)
# Out:
# Missing Age entries: 86

# %%
avg_age = df["Age"].mean()
print("Average Age:", avg_age)
# Out:
# Average Age: 30.272590361445783

# %%
df["Age"].fillna(avg_age, inplace=True)
# Out:
# /tmp/ipython-input-3727184714.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(avg_age, inplace=True)

# %%
avg_5_oldest = df.sort_values("Age", ascending=False).head(5)["Age"].mean()
print("Average age of 5 oldest passengers:", avg_5_oldest)
# Out:
# Average age of 5 oldest passengers: 67.0
